# %% [markdown]
# <img src="../data/zls.svg" width="120" style="float:right; margin: 0 20px 10px 20px;">
#
# # 06 — Advanced Challenges
#
# > **This notebook is optional / stretch material.**
#
# Pick one or more of the challenges below. Use anything you've learned from the previous notebooks.

# %% [markdown]
# ## Challenge 1 — Compare TTS outputs
# Submit two different texts via TTS and compare:
# - duration
# - sample rate
# - any other metadata in the result
#
# ## Challenge 2 — Speaker statistics
# Transcribe `sample_1.wav` with speaker identification enabled, then compute:
# - average word confidence per speaker
# - number of words per speaker
# - total speaking time per speaker
#
# ## Challenge 3 — Batch transcription
# Write a function that takes a list of WAV file paths and transcribes them all, returning a list of results.
#
# ## Challenge 4 — End-to-end pipeline
# Build a mini pipeline: text → TTS → save WAV → STT on that WAV → compare the original text with the transcription.
#
# ## Challenge 5 — Improve the client
# Take the client class from notebook 05 and add:
# - automatic retries on network errors
# - an `export()` method
# - a `tts_to_file()` convenience method

# %% [markdown]
# You can import anything from the previous notebooks — `requests`, `pandas`, the helper functions, or the client class. Add as many cells as you need.

# %%
# Start coding here.
